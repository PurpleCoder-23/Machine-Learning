# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # creating Dataframes

# %%
#form a list of dictionaries(constructed row by row)


list_of_dicts=[
    {'name':'Ginger','breed':'Dachshund','height_cm':22,'weight_kg':10,'date_of_birth':'2019_3_14'},
    {'name':'Scout','breed':'Dalmatian','height_cm':59,'weight_kg':25,'date_of_birth':'2019_05_09'}
    
]

new_dogs=pd.DataFrame(list_of_dicts)
new_dogs
# Out:
#      name      breed  height_cm  weight_kg date_of_birth
# 0  Ginger  Dachshund         22         10     2019_3_14
# 1   Scout  Dalmatian         59         25    2019_05_09

# %%
#form a dictionary of lists(constructed column by column)

dict_of_lists={
    'name':['Ginger','Scout'],
    'breed':['Dachshund','Dalmatian'],
    'height_cm':[22,59],
    'weight_kg':[10,25],
    'date_of_birth':['2019_03_14','2019_05_09']
}

new_dogs=pd.DataFrame(dict_of_lists)
new_dogs
# Out:
#      name      breed  height_cm  weight_kg date_of_birth
# 0  Ginger  Dachshund         22         10    2019_03_14
# 1   Scout  Dalmatian         59         25    2019_05_09

# %% [markdown]
# # Reading and writing csvs

# %%
#
avocado=pd.read_csv(r"C:\Users\91939\Downloads\avocado.csv")

avocado.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %% [markdown]
# # Read csv and assign index

# %%
avocado=pd.read_csv(r"C:\Users\91939\Downloads\avocado.csv",parse_dates=True,index_col='Date')

avocado.head()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# Date
# 2015-12-27           0          1.33      64236.62  1036.74   54454.85
# 2015-12-20           1          1.35      54876.98   674.28   44638.81
# 2015-12-13           2          0.93     118220.22   794.70  109149.67
# 2015-12-06           3          1.08      78992.15  1132.00   71976.41
# 2015-11-29           4          1.28      51039.60   941.48   43838.39
#
#               4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2015-12-27   48.16     8696.87     8603.62       93.25          0.0
# 2015-12-20   58.33     9505.56     9408.07       97.49          0.0
# 2015-12-13  130.50     8145.35     8042.21      103.14          0.0
# 2015-12-06   72.58     5811.16     5677.40      133.76          0.0
# 2015-11-29   75.78     6183.95     5986.26      197.69          0.0
#
#                     type  year  region
# Date
# 2015-12-27  conventional  2015  Albany
# 2015-12-20  conventional  2015  Albany
# 2015-12-13  conventional  2015  Albany
# 2015-12-06  conventional  2015  Albany
# 2015-11-29  conventional  2015  Albany

# %% [markdown]
# # remove index from dataframe.reset_index(drop)

# %%
avocado=avocado.reset_index(drop=True)
avocado.head()
# Out:
#    Unnamed: 0  AveragePrice  Total Volume     4046       4225    4770  \
# 0           0          1.33      64236.62  1036.74   54454.85   48.16
# 1           1          1.35      54876.98   674.28   44638.81   58.33
# 2           2          0.93     118220.22   794.70  109149.67  130.50
# 3           3          1.08      78992.15  1132.00   71976.41   72.58
# 4           4          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
avocado.to_csv('test_write.csv')

# %%
avocado.head()
# Out:
#    Unnamed: 0  AveragePrice  Total Volume     4046       4225    4770  \
# 0           0          1.33      64236.62  1036.74   54454.85   48.16
# 1           1          1.35      54876.98   674.28   44638.81   58.33
# 2           2          0.93     118220.22   794.70  109149.67  130.50
# 3           3          1.08      78992.15  1132.00   71976.41   72.58
# 4           4          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
avocado.tail(3)
# Out:
#        Unnamed: 0  AveragePrice  Total Volume     4046     4225    4770  \
# 18246           9          1.87      13766.76  1191.92  2452.79  727.94
# 18247          10          1.93      16205.22  1527.63  2981.04  727.01
# 18248          11          1.62      17489.58  2894.77  2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18246     9394.11     9351.80       42.31          0.0  organic  2018
# 18247    10969.54    10919.54       50.00          0.0  organic  2018
# 18248    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico

# %%
avocado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(2)
# memory usage: 1.8+ MB

# %%
print(avocado.shape)
# Out:
# (18249, 13)

# %%
avocado.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# std    1.074641e+05  9.862424e+05  7.461785e+05  2.439660e+05   17692.894652
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00       0.000000
# 25%    0.000000e+00  5.088640e+03  2.849420e+03  1.274700e+02       0.000000
# 50%    1.849900e+02  3.974383e+04  2.636282e+04  2.647710e+03       0.000000
# 75%    6.243420e+03  1.107834e+05  8.333767e+04  2.202925e+04     132.500000
# max    2.546439e+06  1.937313e+07  1.338459e+07  5.719097e+06  551693.650000
#
#                year
# count  18249.000000
# mean    2016.147899
# std        0.939938
# min     2015.000000
# 25%     2015.000000
# 50%     2016.000000
# 75%     2017.000000
# max     2018.000000

# %%
avocado.values
# Out:
# array([[0, 1.33, 64236.62, ..., 'conventional', 2015, 'Albany'],
#        [1, 1.35, 54876.98, ..., 'conventional', 2015, 'Albany'],
#        [2, 0.93, 118220.22, ..., 'conventional', 2015, 'Albany'],
#        ...,
#        [9, 1.87, 13766.76, ..., 'organic', 2018, 'WestTexNewMexico'],
#        [10, 1.93, 16205.22, ..., 'organic', 2018, 'WestTexNewMexico'],
#        [11, 1.62, 17489.58, ..., 'organic', 2018, 'WestTexNewMexico']],
#       dtype=object)

# %%
print(avocado.columns)
# Out:
# Index(['Unnamed: 0', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %% [markdown]
# # appending & concatenating series

# %%
even=pd.Series([2,4,6,8,10])
odd=pd.Series([1,3,5,7,9])


res=even.append(odd)
res
# Out:
# C:\Users\91939\AppData\Local\Temp\ipykernel_13964\3255143365.py:5: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   res=even.append(odd)
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# 0     1
# 1     3
# 2     5
# 3     7
# 4     9
# dtype: int64

# %% [markdown]
# # observe index got messed up

# %%
res.reset_index(drop=True)
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# 5     1
# 6     3
# 7     5
# 8     7
# 9     9
# dtype: int64

# %% [markdown]
# # sorting

# %%
avocado.sort_values(['AveragePrice','year'],ascending=[True,False])
# Out:
#        Unnamed: 0  AveragePrice  Total Volume        4046       4225  \
# 15261          43          0.44      64057.04      223.84    4748.88
# 7412           47          0.46    2200550.27  1200632.86  531226.65
# 15473          43          0.48      50890.73      717.57    4138.84
# 15262          44          0.49      44024.03      252.79    4472.68
# 1716            0          0.49    1137707.43   738314.80  286858.37
# ...           ...           ...           ...         ...        ...
# 16720          18          3.04      12656.32      419.06    4851.90
# 16055          42          3.05       2068.26     1043.83      77.36
# 14124           7          3.12      19043.80     5898.49   10039.34
# 17428          37          3.17       3018.56     1255.55      82.31
# 14125           8          3.25      16700.94     2325.93   11142.85
#
#            4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 15261      0.00    59084.32      638.68    58445.64         0.00
# 7412   18324.93   450365.83   113752.17   330583.10      6030.56
# 15473      0.00    46034.32     1385.06    44649.26         0.00
# 15262      0.00    39298.56      600.00    38698.56         0.00
# 1716   11642.46   100891.80    70749.02    30142.78         0.00
# ...         ...         ...         ...         ...          ...
# 16720    145.09     7240.27     6960.97      279.30         0.00
# 16055      0.00      947.07      926.67       20.40         0.00
# 14124      0.00     3105.97     3079.30       26.67         0.00
# 17428      0.00     1680.70     1542.22      138.48         0.00
# 14125      0.00     3232.16     3232.16        0.00         0.00
#
#                type  year             region
# 15261       organic  2017   CincinnatiDayton
# 7412   conventional  2017      PhoenixTucson
# 15473       organic  2017            Detroit
# 15262       organic  2017   CincinnatiDayton
# 1716   conventional  2015      PhoenixTucson
# ...             ...   ...                ...
# 16720       organic  2017  RaleighGreensboro
# 16055       organic  2017  MiamiFtLauderdale
# 14124       organic  2016       SanFrancisco
# 17428       organic  2017              Tampa
# 14125       organic  2016       SanFrancisco
#
# [18249 rows x 13 columns]

# %% [markdown]
# # Subsetting

# %%
avocado['AveragePrice']
# Out:
# 0        1.33
# 1        1.35
# 2        0.93
# 3        1.08
# 4        1.28
#          ...
# 18244    1.63
# 18245    1.71
# 18246    1.87
# 18247    1.93
# 18248    1.62
# Name: AveragePrice, Length: 18249, dtype: float64

# %%
#subsetting multiple columns
avocado[['AveragePrice']]
# Out:
#        AveragePrice
# 0              1.33
# 1              1.35
# 2              0.93
# 3              1.08
# 4              1.28
# ...             ...
# 18244          1.63
# 18245          1.71
# 18246          1.87
# 18247          1.93
# 18248          1.62
#
# [18249 rows x 1 columns]

# %%
avocado['AveragePrice']<1
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 18244    False
# 18245    False
# 18246    False
# 18247    False
# 18248    False
# Name: AveragePrice, Length: 18249, dtype: bool

# %%
#this will print only the rows with price<1

avocado[avocado['AveragePrice']<1]
# Out:
#        Unnamed: 0  AveragePrice  Total Volume      4046       4225    4770  \
# 2               2          0.93     118220.22    794.70  109149.67  130.50
# 6               6          0.99      83453.76   1368.92   73672.72   93.26
# 7               7          0.98     109428.33    703.75  101815.36   80.00
# 13             13          0.99     106803.39   1204.88   99409.21  154.84
# 43             43          0.99      55595.74    629.46   45633.34  181.49
# ...           ...           ...           ...       ...        ...     ...
# 17169          43          0.99     155011.12  35367.23    5175.81    5.91
# 17170          44          0.99     171145.00  34520.03    6936.39    0.00
# 17536          39          0.98     402676.23  34093.33   58330.53  207.85
# 17537          40          0.90     456645.91  36169.35   51398.72  139.55
# 17540          43          0.99     367519.17  61166.48   55123.99  126.80
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 2         8145.35     8042.21      103.14          0.0  conventional  2015
# 6         8318.86     8196.81      122.05          0.0  conventional  2015
# 7         6829.22     6266.85      562.37          0.0  conventional  2015
# 13        6034.46     5888.87      145.59          0.0  conventional  2015
# 43        9151.45     8986.06      165.39          0.0  conventional  2015
# ...           ...         ...         ...          ...           ...   ...
# 17169   114462.17    95379.07    19083.10          0.0       organic  2017
# 17170   129688.58   117252.31    12436.27          0.0       organic  2017
# 17536   310044.52   155701.41   154343.11          0.0       organic  2017
# 17537   368938.29   152159.53   216778.76          0.0       organic  2017
# 17540   251101.90   112844.19   138257.71          0.0       organic  2017
#
#              region
# 2            Albany
# 6            Albany
# 7            Albany
# 13           Albany
# 43           Albany
# ...             ...
# 17169  SouthCentral
# 17170  SouthCentral
# 17536          West
# 17537          West
# 17540          West
#
# [2796 rows x 13 columns]

# %% [markdown]
# # subsetting based on text data

# %%
#it will print all the rows with type-'organinc'

avocado[avocado['type']=='organic']
# Out:
#        Unnamed: 0  AveragePrice  Total Volume     4046     4225    4770  \
# 9126            0          1.83        989.55     8.16    88.59    0.00
# 9127            1          1.89       1163.03    30.24   172.14    0.00
# 9128            2          1.85        995.96    10.44   178.70    0.00
# 9129            3          1.84       1158.42    90.29   104.18    0.00
# 9130            4          1.94        831.69     0.00    94.73    0.00
# ...           ...           ...           ...      ...      ...     ...
# 18244           7          1.63      17074.83  2046.96  1529.20    0.00
# 18245           8          1.71      13888.04  1191.70  3431.50    0.00
# 18246           9          1.87      13766.76  1191.92  2452.79  727.94
# 18247          10          1.93      16205.22  1527.63  2981.04  727.01
# 18248          11          1.62      17489.58  2894.77  2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 9126       892.80      892.80        0.00          0.0  organic  2015
# 9127       960.65      960.65        0.00          0.0  organic  2015
# 9128       806.82      806.82        0.00          0.0  organic  2015
# 9129       963.95      948.52       15.43          0.0  organic  2015
# 9130       736.96      736.96        0.00          0.0  organic  2015
# ...           ...         ...         ...          ...      ...   ...
# 18244    13498.67    13066.82      431.85          0.0  organic  2018
# 18245     9264.84     8940.04      324.80          0.0  organic  2018
# 18246     9394.11     9351.80       42.31          0.0  organic  2018
# 18247    10969.54    10919.54       50.00          0.0  organic  2018
# 18248    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 9126             Albany
# 9127             Albany
# 9128             Albany
# 9129             Albany
# 9130             Albany
# ...                 ...
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico
#
# [9123 rows x 13 columns]

# %% [markdown]
# # subsetting based on dates

# %%
#it will print all the rows eith 'Date'<=2015-02-04

avocado[avocado['Date']<='2015-02-04']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 3
#       1 #it will print all the rows eith 'Date'<=2015-02-04
# ----> 3 avocado[avocado['Date']<='2015-02-04']
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Date'

# %%
#it will print all the rows with 'Date' before 2015-02-04 and type=organic

avocado[(avocado['Date']<'2015-02-04')&(avocado['type']=='organic')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 3
#       1 #it will print all the rows with 'Date' before 2015-02-04 and type=organic
# ----> 3 avocado[(avocado['Date']<'2015-02-04')&(avocado['type']=='organic')]
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Date'

# %% [markdown]
# # subsetting using .isin()

# %%
#subset the avocado in the region boston or sandiego

regionFilter=avocado['region'].isin(['Boston','SanDiego'])
avocado[regionFilter]
# Out:
#        Unnamed: 0  AveragePrice  Total Volume     4046       4225      4770  \
# 208             0          1.13     450816.39  3886.27  346964.70  13952.56
# 209             1          1.07     489802.88  4912.37  390100.99   5887.72
# 210             2          1.01     549945.76  4641.02  455362.38    219.40
# 211             3          1.02     488679.31  5126.32  407520.22    142.99
# 212             4          1.19     350559.81  3609.25  272719.08    105.86
# ...           ...           ...           ...      ...        ...       ...
# 18100           7          1.81      17454.74  1158.41    7388.27      0.00
# 18101           8          1.91      17579.47  1145.64    8284.41      0.00
# 18102           9          1.95      18676.37  1088.49    9282.37      0.00
# 18103          10          1.81      21770.02  3285.98   14338.52      0.00
# 18104          11          2.06      16746.82  5150.82    9366.31      0.00
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 208      86012.86    85913.60       99.26          0.0  conventional  2015
# 209      88901.80    88768.47      133.33          0.0  conventional  2015
# 210      89722.96    89523.38      199.58          0.0  conventional  2015
# 211      75889.78    75666.22      223.56          0.0  conventional  2015
# 212      74125.62    73864.52      261.10          0.0  conventional  2015
# ...           ...         ...         ...          ...           ...   ...
# 18100     8908.06     8908.06        0.00          0.0       organic  2018
# 18101     8149.42     8149.42        0.00          0.0       organic  2018
# 18102     8305.51     8305.51        0.00          0.0       organic  2018
# 18103     4145.52     4145.52        0.00          0.0       organic  2018
# 18104     2229.69     2229.69        0.00          0.0       organic  2018
#
#          region
# 208      Boston
# 209      Boston
# 210      Boston
# 211      Boston
# 212      Boston
# ...         ...
# 18100  SanDiego
# 18101  SanDiego
# 18102  SanDiego
# 18103  SanDiego
# 18104  SanDiego
#
# [676 rows x 13 columns]

# %% [markdown]
# # Multiple parameter Filtering

# %%
#subset the avocado in the region Boston or SanDiego in the year 2016 or 2017
regionFilter=avocado['region'].isin(['Boston','SanDiego'])
yearFilter=avocado['year'].isin(['2016','2017'])
avocado[regionFilter & yearFilter]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, AveragePrice, Total Volume, 4046, 4225, 4770, Total Bags, Small Bags, Large Bags, XLarge Bags, type, year, region]
# Index: []

# %% [markdown]
# # detecting missing values.isna()

# %%
avocado.isna()
# Out:
#        Unnamed: 0  AveragePrice  Total Volume   4046   4225   4770  \
# 0           False         False         False  False  False  False
# 1           False         False         False  False  False  False
# 2           False         False         False  False  False  False
# 3           False         False         False  False  False  False
# 4           False         False         False  False  False  False
# ...           ...           ...           ...    ...    ...    ...
# 18244       False         False         False  False  False  False
# 18245       False         False         False  False  False  False
# 18246       False         False         False  False  False  False
# 18247       False         False         False  False  False  False
# 18248       False         False         False  False  False  False
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags   type   year  region
# 0           False       False       False        False  False  False   False
# 1           False       False       False        False  False  False   False
# 2           False       False       False        False  False  False   False
# 3           False       False       False        False  False  False   False
# 4           False       False       False        False  False  False   False
# ...           ...         ...         ...          ...    ...    ...     ...
# 18244       False       False       False        False  False  False   False
# 18245       False       False       False        False  False  False   False
# 18246       False       False       False        False  False  False   False
# 18247       False       False       False        False  False  False   False
# 18248       False       False       False        False  False  False   False
#
# [18249 rows x 13 columns]

# %% [markdown]
# # we can use .any() function to get a concise info

# %%
avocado.isna().any()
# Out:
# Unnamed: 0      False
# AveragePrice    False
# Total Volume    False
# 4046            False
# 4225            False
# 4770            False
# Total Bags      False
# Small Bags      False
# Large Bags      False
# XLarge Bags     False
# type            False
# year            False
# region          False
# dtype: bool

# %% [markdown]
# # counting missing values

# %%
avocado.isna().sum()
# Out:
# Unnamed: 0      0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# # removing missing values

# %%
avocado.dropna()
# Out:
#        Unnamed: 0  AveragePrice  Total Volume     4046       4225    4770  \
# 0               0          1.33      64236.62  1036.74   54454.85   48.16
# 1               1          1.35      54876.98   674.28   44638.81   58.33
# 2               2          0.93     118220.22   794.70  109149.67  130.50
# 3               3          1.08      78992.15  1132.00   71976.41   72.58
# 4               4          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244           7          1.63      17074.83  2046.96    1529.20    0.00
# 18245           8          1.71      13888.04  1191.70    3431.50    0.00
# 18246           9          1.87      13766.76  1191.92    2452.79  727.94
# 18247          10          1.93      16205.22  1527.63    2981.04  727.01
# 18248          11          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0         8696.87     8603.62       93.25          0.0  conventional  2015
# 1         9505.56     9408.07       97.49          0.0  conventional  2015
# 2         8145.35     8042.21      103.14          0.0  conventional  2015
# 3         5811.16     5677.40      133.76          0.0  conventional  2015
# 4         6183.95     5986.26      197.69          0.0  conventional  2015
# ...           ...         ...         ...          ...           ...   ...
# 18244    13498.67    13066.82      431.85          0.0       organic  2018
# 18245     9264.84     8940.04      324.80          0.0       organic  2018
# 18246     9394.11     9351.80       42.31          0.0       organic  2018
# 18247    10969.54    10919.54       50.00          0.0       organic  2018
# 18248    12014.15    11988.14       26.01          0.0       organic  2018
#
#                  region
# 0                Albany
# 1                Albany
# 2                Albany
# 3                Albany
# 4                Albany
# ...                 ...
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico
#
# [18249 rows x 13 columns]

# %%
meanVal=avocado['AveragePrice'].mean()
avocado.fillna(meanVal)
# Out:
#        Unnamed: 0  AveragePrice  Total Volume     4046       4225    4770  \
# 0               0          1.33      64236.62  1036.74   54454.85   48.16
# 1               1          1.35      54876.98   674.28   44638.81   58.33
# 2               2          0.93     118220.22   794.70  109149.67  130.50
# 3               3          1.08      78992.15  1132.00   71976.41   72.58
# 4               4          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244           7          1.63      17074.83  2046.96    1529.20    0.00
# 18245           8          1.71      13888.04  1191.70    3431.50    0.00
# 18246           9          1.87      13766.76  1191.92    2452.79  727.94
# 18247          10          1.93      16205.22  1527.63    2981.04  727.01
# 18248          11          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0         8696.87     8603.62       93.25          0.0  conventional  2015
# 1         9505.56     9408.07       97.49          0.0  conventional  2015
# 2         8145.35     8042.21      103.14          0.0  conventional  2015
# 3         5811.16     5677.40      133.76          0.0  conventional  2015
# 4         6183.95     5986.26      197.69          0.0  conventional  2015
# ...           ...         ...         ...          ...           ...   ...
# 18244    13498.67    13066.82      431.85          0.0       organic  2018
# 18245     9264.84     8940.04      324.80          0.0       organic  2018
# 18246     9394.11     9351.80       42.31          0.0       organic  2018
# 18247    10969.54    10919.54       50.00          0.0       organic  2018
# 18248    12014.15    11988.14       26.01          0.0       organic  2018
#
#                  region
# 0                Albany
# 1                Albany
# 2                Albany
# 3                Albany
# 4                Albany
# ...                 ...
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico
#
# [18249 rows x 13 columns]

# %% [markdown]
# # adding a new column

# %%
avocado['AveragePricePer100']=avocado['AveragePrice']*100
avocado
# Out:
#        Unnamed: 0  AveragePrice  Total Volume     4046       4225    4770  \
# 0               0          1.33      64236.62  1036.74   54454.85   48.16
# 1               1          1.35      54876.98   674.28   44638.81   58.33
# 2               2          0.93     118220.22   794.70  109149.67  130.50
# 3               3          1.08      78992.15  1132.00   71976.41   72.58
# 4               4          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244           7          1.63      17074.83  2046.96    1529.20    0.00
# 18245           8          1.71      13888.04  1191.70    3431.50    0.00
# 18246           9          1.87      13766.76  1191.92    2452.79  727.94
# 18247          10          1.93      16205.22  1527.63    2981.04  727.01
# 18248          11          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0         8696.87     8603.62       93.25          0.0  conventional  2015
# 1         9505.56     9408.07       97.49          0.0  conventional  2015
# 2         8145.35     8042.21      103.14          0.0  conventional  2015
# 3         5811.16     5677.40      133.76          0.0  conventional  2015
# 4         6183.95     5986.26      197.69          0.0  conventional  2015
# ...           ...         ...         ...          ...           ...   ...
# 18244    13498.67    13066.82      431.85          0.0       organic  2018
# 18245     9264.84     8940.04      324.80          0.0       organic  2018
# 18246     9394.11     9351.80       42.31          0.0       organic  2018
# 18247    10969.54    10919.54       50.00          0.0       organic  2018
# 18248    12014.15    11988.14       26.01          0.0       organic  2018
#
#                  region  AveragePricePer100
# 0                Albany               133.0
# 1                Albany               135.0
# 2                Albany                93.0
# 3                Albany               108.0
# 4                Albany               128.0
# ...                 ...                 ...
# 18244  WestTexNewMexico               163.0
# 18245  WestTexNewMexico               171.0
# 18246  WestTexNewMexico               187.0
# 18247  WestTexNewMexico               193.0
# 18248  WestTexNewMexico               162.0
#
# [18249 rows x 14 columns]

# %% [markdown]
# # deleting columns in dataframe.drop(lst,axis=1)

# %%
avocado.drop(['AveragePricePer100'],axis=1)
# Out:
#        Unnamed: 0  AveragePrice  Total Volume     4046       4225    4770  \
# 0               0          1.33      64236.62  1036.74   54454.85   48.16
# 1               1          1.35      54876.98   674.28   44638.81   58.33
# 2               2          0.93     118220.22   794.70  109149.67  130.50
# 3               3          1.08      78992.15  1132.00   71976.41   72.58
# 4               4          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244           7          1.63      17074.83  2046.96    1529.20    0.00
# 18245           8          1.71      13888.04  1191.70    3431.50    0.00
# 18246           9          1.87      13766.76  1191.92    2452.79  727.94
# 18247          10          1.93      16205.22  1527.63    2981.04  727.01
# 18248          11          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0         8696.87     8603.62       93.25          0.0  conventional  2015
# 1         9505.56     9408.07       97.49          0.0  conventional  2015
# 2         8145.35     8042.21      103.14          0.0  conventional  2015
# 3         5811.16     5677.40      133.76          0.0  conventional  2015
# 4         6183.95     5986.26      197.69          0.0  conventional  2015
# ...           ...         ...         ...          ...           ...   ...
# 18244    13498.67    13066.82      431.85          0.0       organic  2018
# 18245     9264.84     8940.04      324.80          0.0       organic  2018
# 18246     9394.11     9351.80       42.31          0.0       organic  2018
# 18247    10969.54    10919.54       50.00          0.0       organic  2018
# 18248    12014.15    11988.14       26.01          0.0       organic  2018
#
#                  region
# 0                Albany
# 1                Albany
# 2                Albany
# 3                Albany
# 4                Albany
# ...                 ...
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico
#
# [18249 rows x 13 columns]

# %% [markdown]
# # summary statistics

# %%
#mean of averageprice of avocado
avocado['AveragePrice'].mean()
# Out:
# 1.405978409775878

# %% [markdown]
# # summarixing dates

# %%
avocado['Date'].max()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 avocado['Date'].max()
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Date'

# %% [markdown]
# # .agg() method

# %%
def pct30(column):
    return column.quantile(0.3)
def pct50(column):
    return column.quantile(0.5)

avocado[['AveragePrice','Total Bags']].agg([pct30,pct50])
# Out:
#        AveragePrice  Total Bags
# pct30          1.15    7316.634
# pct50          1.37   39743.830

# %% [markdown]
# # droping duplicate names .drop_duplicates

# %%
temp=avocado.drop_duplicates(subset=['year'])

# %%
temp
# Out:
#       Unnamed: 0  AveragePrice  Total Volume      4046       4225    4770  \
# 0              0          1.33      64236.62   1036.74   54454.85   48.16
# 2808           0          1.52      73341.73   3202.39   58280.33  426.92
# 5616           0          1.47     113514.42   2622.70  101135.53   20.25
# 8478           0          1.57     149396.50  16361.69  109045.03   65.45
#
#       Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0        8696.87     8603.62       93.25         0.00  conventional  2015
# 2808    11432.09    11017.32      411.83         2.94  conventional  2016
# 5616     9735.94     5556.98     4178.96         0.00  conventional  2017
# 8478    23924.33    19273.80     4270.53       380.00  conventional  2018
#
#       region  AveragePricePer100
# 0     Albany               133.0
# 2808  Albany               152.0
# 5616  Albany               147.0
# 8478  Albany               157.0

# %% [markdown]
# # count categorical data .value_counts()|

# %%
avocado['year'].value_counts(sort=True,ascending=False)
# Out:
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: year, dtype: int64

# %% [markdown]
# # grouped summaries.groupby(col)

# %%
#goup by multilple columns and perform multiple summary statistic operations

avocado.groupby(['year','type'])['AveragePrice'].agg([min,max,np.mean,np.median])
# Out:
#                     min   max      mean  median
# year type
# 2015 conventional  0.49  1.59  1.077963    1.08
#      organic       0.81  2.79  1.673324    1.67
# 2016 conventional  0.51  2.20  1.105595    1.08
#      organic       0.58  3.25  1.571684    1.53
# 2017 conventional  0.46  2.22  1.294888    1.30
#      organic       0.44  3.17  1.735521    1.72
# 2018 conventional  0.56  1.74  1.127886    1.14
#      organic       1.01  2.30  1.567176    1.55

# %% [markdown]
# # pivot table

# %%
# this is the same table we build in the previus cel but using pivot table

avocado.pivot_table(index=['year','type'],aggfunc=[min,max,np.mean,np.median],values='AveragePrice')
# Out:
#                            min          max         mean       median
#                   AveragePrice AveragePrice AveragePrice AveragePrice
# year type
# 2015 conventional         0.49         1.59     1.077963         1.08
#      organic              0.81         2.79     1.673324         1.67
# 2016 conventional         0.51         2.20     1.105595         1.08
#      organic              0.58         3.25     1.571684         1.53
# 2017 conventional         0.46         2.22     1.294888         1.30
#      organic              0.44         3.17     1.735521         1.72
# 2018 conventional         0.56         1.74     1.127886         1.14
#      organic              1.01         2.30     1.567176         1.55

# %% [markdown]
# # explicit indexes

# %%
regionIndex=avocado.set_index(['region'])
regionIndex
# Out:
#                   Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# region
# Albany                     0          1.33      64236.62  1036.74   54454.85
# Albany                     1          1.35      54876.98   674.28   44638.81
# Albany                     2          0.93     118220.22   794.70  109149.67
# Albany                     3          1.08      78992.15  1132.00   71976.41
# Albany                     4          1.28      51039.60   941.48   43838.39
# ...                      ...           ...           ...      ...        ...
# WestTexNewMexico           7          1.63      17074.83  2046.96    1529.20
# WestTexNewMexico           8          1.71      13888.04  1191.70    3431.50
# WestTexNewMexico           9          1.87      13766.76  1191.92    2452.79
# WestTexNewMexico          10          1.93      16205.22  1527.63    2981.04
# WestTexNewMexico          11          1.62      17489.58  2894.77    2356.13
#
#                     4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# region
# Albany             48.16     8696.87     8603.62       93.25          0.0
# Albany             58.33     9505.56     9408.07       97.49          0.0
# Albany            130.50     8145.35     8042.21      103.14          0.0
# Albany             72.58     5811.16     5677.40      133.76          0.0
# Albany             75.78     6183.95     5986.26      197.69          0.0
# ...                  ...         ...         ...         ...          ...
# WestTexNewMexico    0.00    13498.67    13066.82      431.85          0.0
# WestTexNewMexico    0.00     9264.84     8940.04      324.80          0.0
# WestTexNewMexico  727.94     9394.11     9351.80       42.31          0.0
# WestTexNewMexico  727.01    10969.54    10919.54       50.00          0.0
# WestTexNewMexico  224.53    12014.15    11988.14       26.01          0.0
#
#                           type  year  AveragePricePer100
# region
# Albany            conventional  2015               133.0
# Albany            conventional  2015               135.0
# Albany            conventional  2015                93.0
# Albany            conventional  2015               108.0
# Albany            conventional  2015               128.0
# ...                        ...   ...                 ...
# WestTexNewMexico       organic  2018               163.0
# WestTexNewMexico       organic  2018               171.0
# WestTexNewMexico       organic  2018               187.0
# WestTexNewMexico       organic  2018               193.0
# WestTexNewMexico       organic  2018               162.0
#
# [18249 rows x 13 columns]

# %%
# we can simply do
regionIndex.loc[['Albany','WestTexNewMexico']]
# Out:
#                   Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# region
# Albany                     0          1.33      64236.62  1036.74   54454.85
# Albany                     1          1.35      54876.98   674.28   44638.81
# Albany                     2          0.93     118220.22   794.70  109149.67
# Albany                     3          1.08      78992.15  1132.00   71976.41
# Albany                     4          1.28      51039.60   941.48   43838.39
# ...                      ...           ...           ...      ...        ...
# WestTexNewMexico           7          1.63      17074.83  2046.96    1529.20
# WestTexNewMexico           8          1.71      13888.04  1191.70    3431.50
# WestTexNewMexico           9          1.87      13766.76  1191.92    2452.79
# WestTexNewMexico          10          1.93      16205.22  1527.63    2981.04
# WestTexNewMexico          11          1.62      17489.58  2894.77    2356.13
#
#                     4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# region
# Albany             48.16     8696.87     8603.62       93.25          0.0
# Albany             58.33     9505.56     9408.07       97.49          0.0
# Albany            130.50     8145.35     8042.21      103.14          0.0
# Albany             72.58     5811.16     5677.40      133.76          0.0
# Albany             75.78     6183.95     5986.26      197.69          0.0
# ...                  ...         ...         ...         ...          ...
# WestTexNewMexico    0.00    13498.67    13066.82      431.85          0.0
# WestTexNewMexico    0.00     9264.84     8940.04      324.80          0.0
# WestTexNewMexico  727.94     9394.11     9351.80       42.31          0.0
# WestTexNewMexico  727.01    10969.54    10919.54       50.00          0.0
# WestTexNewMexico  224.53    12014.15    11988.14       26.01          0.0
#
#                           type  year  AveragePricePer100
# region
# Albany            conventional  2015               133.0
# Albany            conventional  2015               135.0
# Albany            conventional  2015                93.0
# Albany            conventional  2015               108.0
# Albany            conventional  2015               128.0
# ...                        ...   ...                 ...
# WestTexNewMexico       organic  2018               163.0
# WestTexNewMexico       organic  2018               171.0
# WestTexNewMexico       organic  2018               187.0
# WestTexNewMexico       organic  2018               193.0
# WestTexNewMexico       organic  2018               162.0
#
# [673 rows x 13 columns]

# %% [markdown]
# # visualizing your data

# %%
#histograms
avocado['AveragePrice'].hist(bins=20)
plt.show()
